# %%
from sklearn.utils.random import sample_without_replacement
sample_without_replacement(1000,20,random_state=None,method='tracking_selection')
# Out:
# array([168, 364, 667, 695, 828, 111, 468, 952, 621, 514,   7, 412, 797,
#        453, 357, 132, 250, 844, 521, 985])

# %%
sample_without_replacement(10000,305,random_state=2,method='auto')
# Out:
# array([7878, 3224, 1919, 4432, 4835, 4895, 7269, 1451, 1742, 4628, 7053,
#        3634, 3215, 3707, 7066, 2965, 8644, 6469, 8921, 1254, 7356,  180,
#        2167, 5975, 2105, 7054, 6145, 2929, 5460, 6810, 8500,  801, 2024,
#        1345, 3279,  554,  946, 5165, 1906, 1713, 1297, 4588, 4236,  338,
#        2628, 3340, 7570, 1810,  127, 3709, 6067, 9117, 7941, 7013, 7521,
#         975, 5286,  301,  400, 1278, 8131, 9253, 8256, 9561, 5844, 1371,
#        1189, 2207, 2113, 7023, 7650, 7931, 9288, 4072, 2877,  617, 7948,
#        2942, 1219, 4801, 5097, 8433, 9721, 1800, 9355, 4140, 1367, 5425,
#         110, 4854, 1339, 8482, 7542,  749, 2245, 8223, 7145, 7062, 6329,
#        6632,  616, 1751, 3230, 9460, 3901, 1496, 1282, 7016, 9057, 8135,
#        8686,  793, 8881,  188, 2427, 3307, 7509, 5199, 6313, 5218, 3343,
#        9572, 2750, 6762, 3704, 3416, 2352, 5521, 1446, 6873, 5130, 8767,
#        2018, 3227, 2140, 4161, 2596, 6084, 7781, 3938, 1460, 6574,  659,
# ...

# %%
sample_without_replacement(10,1,random_state=2,method='pool')
# Out:
# array([8])
